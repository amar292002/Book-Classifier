# %%
import numpy as np
import pandas as pd

# %%
Book=pd.read_csv("Books.csv")
Rating=pd.read_csv("Ratings.csv")
User=pd.read_csv("Users.csv")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4500\1020967084.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   Book=pd.read_csv("Books.csv")

# %%
Book.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
Rating.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726   155061224            5
# 2   276727   446520802            0
# 3   276729  052165615X            3
# 4   276729   521795028            6

# %%
User.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
Book.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271358 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %%
Rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1048575 non-null  int64
#  1   ISBN         1048575 non-null  object
#  2   Book-Rating  1048575 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 24.0+ MB

# %%
User.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB

# %%
Book.describe()
# Out:
#               ISBN      Book-Title      Book-Author  Year-Of-Publication  \
# count       271360          271360           271358               271360
# unique      271360          242135           102022                  202
# top     020130998X  Selected Poems  Agatha Christie                 2002
# freq             1              27              632                13903
#
#         Publisher                                        Image-URL-S  \
# count      271358                                             271360
# unique      16807                                             271044
# top     Harlequin  http://images.amazon.com/images/P/155936078X.0...
# freq         7535                                                  2
#
#                                               Image-URL-M  \
# count                                              271360
# unique                                             271044
# top     http://images.amazon.com/images/P/155936078X.0...
# ...

# %%
Book.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
Rating=Rating.merge(User,on="User-ID")

# %%
Book=Book.merge(Rating,on="ISBN")

# %%
Book.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179091 entries, 0 to 179090
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 179091 non-null  object
#  1   Book-Title           179091 non-null  object
#  2   Book-Author          179090 non-null  object
#  3   Year-Of-Publication  179091 non-null  object
#  4   Publisher            179089 non-null  object
#  5   Image-URL-S          179091 non-null  object
#  6   Image-URL-M          179091 non-null  object
#  7   Image-URL-L          179088 non-null  object
#  8   User-ID              179091 non-null  int64
#  9   Book-Rating          179091 non-null  int64
#  10  Location             179091 non-null  object
#  11  Age                  134321 non-null  float64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 16.4+ MB

# %%
Book.isnull().sum()
# Out:
# ISBN                       0
# Book-Title                 0
# Book-Author                1
# Year-Of-Publication        0
# Publisher                  2
# Image-URL-S                0
# Image-URL-M                0
# Image-URL-L                3
# User-ID                    0
# Book-Rating                0
# Location                   0
# Age                    44770
# dtype: int64

# %%
Book['Age']=Book['Age'].fillna(Book['Age'].mean())

# %%
# Book['Age_y']=Book['Age_y'].fillna(Book['Age_y'].mean())

# %%
Book['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
# Book.drop('Age_y',axis=1,inplace=True)

# %%
# Book.drop('Location_y',axis=1,inplace=True)

# %%
Book.rename(columns={"Age_x":"Age"},inplace=True)

# %% [markdown]
# #change age into decimal into int

# %%
Book.sample(5)
# Out:
#               ISBN                                  Book-Title    Book-Author  \
# 9257    3518368540                                  Homo Faber     Max Frisch
# 106694  8807807203  Garzanti - Gli Elefanti: Blues Di Bay City       Chandler
# 9421    031215125X                           The Far Pavilions     M. M. Kaye
# 139570  1565924266        Learning the vi Editor (6th Edition)     Linda Lamb
# 111662  051745999X                                  92 Stories  James Thurber
#
#        Year-Of-Publication               Publisher  \
# 9257                     0   Distribooks Int'l+inc
# 106694                   0             Feltrinelli
# 9421                  1997      St. Martin's Press
# 139570                1998                O'Reilly
# 111662                1987  Random House Value Pub
#
#                                               Image-URL-S  \
# 9257    http://images.amazon.com/images/P/3518368540.0...
# 106694  http://images.amazon.com/images/P/8807807203.0...
# ...

# %%
new_rating=Book.groupby('Book-Author').count()['Book-Rating'].reset_index()

# %%
print(new_rating)
# Out:
#                   Book-Author  Book-Rating
# 0                J. D. Landis            1
# 1                 Mimma Balia            1
# 2                        2000            2
# 3                        2003            1
# 4                 A E Hartink            2
# ...                       ...          ...
# 37703          Â¢ystein LÂ²nn            1
# 37704     Ã?dÃ¶n von HorvÃ¡th            4
# 37705  Ã?Â?dÃ?Â¶n von Horvath            2
# 37706          Ã?Â?pictÃ?Â¨te            2
# 37707          Ã?Â?ric Holder            3
#
# [37708 rows x 2 columns]

# %%
Book.shape
# Out:
# (179091, 12)

# %%
new_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37708 entries, 0 to 37707
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Book-Author  37708 non-null  object
#  1   Book-Rating  37708 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 589.3+ KB

# %%
new_rating.isnull().sum()
# Out:
# Book-Author    0
# Book-Rating    0
# dtype: int64

# %%
avg_rating=Book.groupby('Book-Title').agg({'Book-Rating':np.mean}).reset_index()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4500\262375472.py:1: FutureWarning: The provided callable <function mean at 0x0000021C04D50540> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   avg_rating=Book.groupby('Book-Title').agg({'Book-Rating':np.mean}).reset_index()

# %%
print(avg_rating)
# Out:
#                                               Book-Title  Book-Rating
# 0       Earth Prayers From around the World: 365 Pray...     5.555556
# 1       Final Fantasy Anthology: Official Strategy Gu...     5.000000
# 2       Flight of Fancy: American Heiresses (Zebra Ba...     4.000000
# 3       Little Comic Shop of Horrors (Give Yourself G...     0.000000
# 4                                           Mystery Mile     0.000000
# ...                                                  ...          ...
# 64752                                 Ã?Â?l- Connection.     0.000000
# 64753                                      Ã?Â?lpiraten.     0.000000
# 64754                     Ã?Â?rger mit Produkt X. Roman.     5.250000
# 64755                              Ã?Â?stlich der Berge.     4.000000
# 64756                                  Ã?Â?thique en toc     4.000000
#
# [64757 rows x 2 columns]

# %%
Popular_Book=Book.merge(avg_rating,on='Book-Title')

# %%
print(Popular_Book)
# Out:
#               ISBN                                         Book-Title  \
# 0       074322678X            Where You'll Find Me: And Other Stories
# 1       080652121X  Hitler's Secret Bankers: The Myth of Swiss Neu...
# 2       1552041778                                           Jane Doe
# 3       1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 4       1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# ...            ...                                                ...
# 179086  8401424828                                 Hija de Homero, La
# 179087  1565120752                                       Winter Birds
# 179088  067167806X  From Winchester to Cedar Creek: The Shenandoah...
# 179089  1561709085  Inner Peace for Busy People: Simple Strategies...
# 179090  8874960018           L'Occhio Nero Al Panda Gliel'ho Fatto IO
#
#                   Book-Author Year-Of-Publication  \
# 0                 Ann Beattie                2002
# ...

# %%
Popular_Book.head(10)
# Out:
#          ISBN                                         Book-Title  \
# 0  074322678X            Where You'll Find Me: And Other Stories
# 1  080652121X  Hitler's Secret Bankers: The Myth of Swiss Neu...
# 2  1552041778                                           Jane Doe
# 3  1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 4  1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 5  1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 6  1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 7  1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 8  1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 9  1567407781       The Witchfinder (Amos Walker Mystery Series)
#
#          Book-Author Year-Of-Publication                 Publisher  \
# 0        Ann Beattie                2002                  Scribner
# 1         Adam Lebor                2000             Citadel Press
# ...

# %%
import nltk

# %%
Popular_Book.drop(columns=["Age", "Book-Rating_y"], inplace=True)

# %%
Popular_Book.drop(columns=['Image-URL-S','Image-URL-M','Image-URL-L'],inplace=True)

# %%
Popular_Book.head(10)
# Out:
#          ISBN                                         Book-Title  \
# 0  074322678X            Where You'll Find Me: And Other Stories
# 1  080652121X  Hitler's Secret Bankers: The Myth of Swiss Neu...
# 2  1552041778                                           Jane Doe
# 3  1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 4  1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 5  1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 6  1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 7  1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 8  1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 9  1567407781       The Witchfinder (Amos Walker Mystery Series)
#
#          Book-Author Year-Of-Publication                 Publisher  User-ID  \
# 0        Ann Beattie                2002                  Scribner        8
# 1         Adam Lebor                2000             Citadel Press        8
# ...

# %%
Popular_Book.rename(columns={'Book-Rating_x':'Ratings'}, inplace=True)

# %%
Popular_Book.iloc[20].ISBN
# Out:
# '1841721522'

# %%
print(Popular_Book)
# Out:
#               ISBN                                         Book-Title  \
# 0       074322678X            Where You'll Find Me: And Other Stories
# 1       080652121X  Hitler's Secret Bankers: The Myth of Swiss Neu...
# 2       1552041778                                           Jane Doe
# 3       1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 4       1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# ...            ...                                                ...
# 179086  8401424828                                 Hija de Homero, La
# 179087  1565120752                                       Winter Birds
# 179088  067167806X  From Winchester to Cedar Creek: The Shenandoah...
# 179089  1561709085  Inner Peace for Busy People: Simple Strategies...
# 179090  8874960018           L'Occhio Nero Al Panda Gliel'ho Fatto IO
#
#                   Book-Author Year-Of-Publication  \
# 0                 Ann Beattie                2002
# ...

# %%
Popular_Book.head(8)
# Out:
#          ISBN                                         Book-Title  \
# 0  074322678X            Where You'll Find Me: And Other Stories
# 1  080652121X  Hitler's Secret Bankers: The Myth of Swiss Neu...
# 2  1552041778                                           Jane Doe
# 3  1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 4  1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 5  1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 6  1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
# 7  1558746218  A Second Chicken Soup for the Woman's Soul (Ch...
#
#      Book-Author Year-Of-Publication              Publisher  User-ID  Ratings  \
# 0    Ann Beattie                2002               Scribner        8        5
# 1     Adam Lebor                2000          Citadel Press        8        0
# 2   R. J. Kaiser                1999             Mira Books        8        5
# ...

# %%
# sorted(list(enumerate(cs[0])),reverse=True,key=lambda x: x[1])[1:6]

# %%
Popular_Book['Book_summary']=Popular_Book['Book-Title'] + Popular_Book['Book-Author']

# %%
Popular_Book.iloc[6].Book_summary
# Out:
# "A Second Chicken Soup for the Woman's Soul (Chicken Soup for the Soul Series)Jack Canfield"

# %%
Popular_Book['Book_summary']=Popular_Book['Book_summary'].astype(str)

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
def stem(text):
    y=[]

    for i in text.split():
        y.append(ps.stem(i))

    return " ".join(y)

# %%
Popular_Book['Book_summary'].apply(stem)
# Out:
# 0         where you'll find me: and other storiesann beatti
# 1         hitler' secret bankers: the myth of swiss neut...
# 2                                      jane doer. j. kaiser
# 3         a second chicken soup for the woman' soul (chi...
# 4         a second chicken soup for the woman' soul (chi...
#                                 ...
# 179086                       hija de homero, larobert grave
# 179087                             winter birdsjim grimsley
# 179088    from winchest to cedar creek: the shenandoah c...
# 179089    inner peac for busi people: simpl strategi for...
# 179090    l'occhio nero al panda gliel'ho fatto iopaolo ...
# Name: Book_summary, Length: 179091, dtype: object

# %%
Popular_Book.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179091 entries, 0 to 179090
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 179091 non-null  object
#  1   Book-Title           179091 non-null  object
#  2   Book-Author          179090 non-null  object
#  3   Year-Of-Publication  179091 non-null  object
#  4   Publisher            179089 non-null  object
#  5   User-ID              179091 non-null  int64
#  6   Ratings              179091 non-null  int64
#  7   Location             179091 non-null  object
#  8   Book_summary         179091 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 12.3+ MB

# %%
Popular_Book.iloc[500].Book_summary
# Out:
# "Corelli's Mandolin : A NovelLOUIS DE BERNIERES"

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cv = CountVectorizer(max_features = 5000,stop_words = 'english')
vectors=cv.fit_transform(Popular_Book['Book_summary'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 cv = CountVectorizer(max_features = 5000,stop_words = 'english')
#       2 vectors=cv.fit_transform(Popular_Book['Book_summary'])
#
# NameError: name 'CountVectorizer' is not defined

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(vectors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 3
#       1 from sklearn.metrics.pairwise import cosine_similarity
# ----> 3 similarity = cosine_similarity(vectors)
#
# NameError: name 'vectors' is not defined

# %%
sorted(list(enumerate(similarity[0])),reverse=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 sorted(list(enumerate(similarity[0])),reverse=True)
#
# NameError: name 'similarity' is not defined
